# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
data = pd.read_excel('card transactions.xlsx')

# %%
# only use purchase type transactions
df = data.loc[data['Transtype'] == 'P']

# %%
df.shape
# Out:
# (96398, 10)

# %%
df.columns
# Out:
# Index(['Recnum', 'Cardnum', 'Date', 'Merchnum', 'Merch description',
#        'Merch state', 'Merch zip', 'Transtype', 'Amount', 'Fraud'],
#       dtype='object')

# %%
df[df['Merch description'] == '0000000000000000000000']
# Out:
#        Recnum     Cardnum       Date       Merchnum       Merch description  \
# 83923   83924  5142182645 2010-10-28  8168600400097  0000000000000000000000
# 92542   92543  5142185554 2010-12-10  8168600400097  0000000000000000000000
# 92570   92571  5142185554 2010-12-10  8168600400097  0000000000000000000000
#
#       Merch state  Merch zip Transtype  Amount  Fraud
# 83923          WA    98052.0         P  463.86      0
# 92542          WA    98052.0         P  127.87      0
# 92570          WA    98052.0         P  769.70      0

# %% [markdown]
# ## Fix Missing Values

# %% [markdown]
# ### Fix Missing Zipcode & Adjust some entries

# %%
import googlemaps
gmaps = googlemaps.Client(key='apikey')

# %% [markdown]
# **Step 1: fix missing zipcode with Merch state and Merch description**

# %%
# Step 1: fix missing zipcode with Merch state and Merch description
temp = df[(df['Merch zip'].isnull()) & (df['Merch state'].notnull())]
df['Merch zip'] = df['Merch zip'].fillna(0)

for i in temp.index:
    s = df.loc[i]['Merch description']
    result = " ".join(re.split("[^a-zA-Z]+", s))
    address = result + ' , ' + df.loc[i]['Merch state']
    location = gmaps.geocode(address)
    
    if len(location) == 0:   #some unrecognized address
        pass
    else:
        if location[0]['address_components'][-1]['types'] == ['postal_code']:
            zipcode = location[0]['address_components'][-1]['long_name']
            df.loc[df.index == i, 'Merch zip'] = zipcode
        else:
            zipcode = location[0]['address_components'][-2]['long_name']
            df.loc[df.index == i, 'Merch zip'] = zipcode

# %% [markdown]
# **Step 2: fix zipcode that is not 5 digits**

# %%
# Step 2: fix zipcode that is not 5 digits
df['Merch zip'] = df['Merch zip'].astype(str)

# %%
not_5_zip = []

for i,j in zip(df['Merch zip'], df.index):
    if i[:5].isdecimal() == False:
        not_5_zip.append(j)
    else:
        continue

# %%
# 4 digit zipcode may start with 0
temp = df[df.index.isin(not_5_zip)]['Merch zip']

four_zip = []

for i,j in zip(temp.str[:4],temp.index):
    if i.isdecimal():
        four_zip.append(j)
    else:
        continue

# %%
# states that zipcode start with 0 
state_zip_0 = ['CT', 'MA', 'ME', 'NH', 'NJ', 'PR', 'RI', 'VT', 'VI']

for i in four_zip:
    if df.loc[i]['Merch state'] in state_zip_0:
        new = '0' + df.loc[i]['Merch zip']
        df.loc[df.index == i, 'Merch zip'] = new

# %% [markdown]
# **Step 3: others**

# %%
others = list(set(not_5_zip) - set(four_zip))

# %%
temp = df[(df.index.isin(others)) & (df['Merch state'].notnull())]
not_found = []

for i in temp.index:
    s = df.loc[i]['Merch description']
    result = " ".join(re.split("[^a-zA-Z]+", s))
    address = result + ' , ' + df.loc[i]['Merch state']
    location = gmaps.geocode(address)
    
    if len(location) == 0:   #some unrecognized address
        not_found.append(i)
        pass
    else:
        if location[0]['address_components'][-1]['types'] == ['postal_code']:
            zipcode = location[0]['address_components'][-1]['long_name']
            df.loc[df.index == i, 'Merch zip'] = zipcode
        else:
            zipcode = location[0]['address_components'][-2]['long_name']
            df.loc[df.index == i, 'Merch zip'] = zipcode

# %%
df[df.index.isin(not_found)]
# Out:
#        Recnum     Cardnum       Date       Merchnum  \
# 10486   10487  5142227402 2010-02-14            NaN
# 13934   13935  5142120389 2010-02-28            NaN
# 20802   20803  5142196337 2010-03-22            NaN
# 20866   20867  5142196337 2010-03-22            NaN
# 21063   21064  5142196337 2010-03-22            NaN
# 21102   21103  5142196337 2010-03-22            NaN
# 22444   22445  5142120389 2010-03-28            NaN
# 30626   30627  5142182005 2010-04-27  6497600064127
# 34906   34907  5142189108 2010-05-11            NaN
# 39956   39957  5142189135 2010-05-29  9006005990206
# 44858   44859  5142296516 2010-06-15            NaN
# 46519   46520  5142115062 2010-06-20            NaN
# 63494   63495  5142309462 2010-08-15   500020081506
# 65288   65289  5142119910 2010-08-21   500020081506
# 65526   65527  5142271289 2010-08-21   500020081506
# 65872   65873  5142276356 2010-08-22            NaN
# 66037   66038  5142188276 2010-08-23            NaN
# 72176   72177  5142250124 2010-09-11  6700017150060
# 72592   72593  5142176897 2010-09-12  9341690509209
# 72957   72958  5142176897 2010-09-13  9341690509209
# 74932   74933  5142250124 2010-09-19  6700017150060
# 75711   75712  5142147188 2010-09-20            NaN
# 80647   80648  5142120389 2010-10-08            NaN
# 88727   88728  5142233478 2010-11-22            NaN
# 95267   95268  5142174305 2010-12-22            NaN
#
#                Merch description Merch state Merch zip Transtype   Amount  \
# 10486     NORTHWEST ECONOMETRICS          BC       0.0         P   577.00
# 13934  LANGEVIN LEARN SERV(US)IN          ON       0.0         P   259.35
# 20802  LANGEVIN LEARNING SERVICE          ON       0.0         P   399.00
# 20866  LANGEVIN LEARNING SERVICE          ON       0.0         P   199.00
# 21063  LANGEVIN LEARNING SERVICE          ON       0.0         P   359.00
# 21102  LANGEVIN LEARNING SERVICE          ON       0.0         P   199.00
# 22444  LANGEVIN LEARN SERV(US)IN          ON       0.0         P   399.00
# 30626       JONES CHROMATOGRAPHY          CO       0.0         P  1479.00
# 34906                  GOC-CCOHS          ON       0.0         P   365.00
# 39956             LYNNON BIOSOFT          PQ       0.0         P   468.00
# 44858     EXIT O DIGITAL SYSTEMS          NS       0.0         P   109.95
# 46519     EXIT O DIGITAL SYSTEMS          NS       0.0         P    69.95
# 63494           U S G S-RMMC-FIN          CO       0.0         P   297.00
# 65288           U S G S-RMMC-FIN          CO       0.0         P    65.00
# 65526           U S G S-RMMC-FIN          CO       0.0         P    13.00
# 65872  LANGEVIN LEARN SERV(US)IN          ON       0.0         P   399.00
# 66037     ECOPOINT/DIESELNET INC          ON       0.0         P   125.00
# 72176     TEXSUN TROPHIE67650010          TX       0.0         P   200.00
# 72592  ELEMENT K PRESS STORE.COM          NY       1.0         P   163.85
# 72957  ELEMENT K PRESS STORE.COM          NY       1.0         P    27.99
# 74932     TEXSUN TROPHIE67650010          TX       0.0         P   345.58
# 75711                  GOC-CCOHS          ON       0.0         P   319.59
# 80647  LANGEVIN LEARNING SERVICE          ON       0.0         P   259.35
# 88727                  GOC-CCOHS          ON       0.0         P   360.00
# 95267                  GOC-CCOHS          ON       0.0         P   435.00
#
#        Fraud
# 10486      0
# 13934      0
# 20802      0
# 20866      0
# 21063      0
# 21102      0
# 22444      0
# 30626      0
# 34906      0
# 39956      0
# 44858      0
# 46519      0
# 63494      0
# 65288      0
# 65526      0
# 65872      0
# 66037      0
# 72176      0
# 72592      0
# 72957      0
# 74932      0
# 75711      0
# 80647      0
# 88727      0
# 95267      0

# %%
# Lower postal code from online source: 
# https://www.swiftestimator.com/SE7Help/CE/help/Miscellaneous/Using_Canadian_Postal_Codes.htm
zip_online = {'ON':'K0G 0A0', 'CO':'80218', 'TX': '75001', 'NY': '10081', 'NS': 'B0A 0A0', 
              'PQ': 'G0A 0A0', 'BC': 'V5K 0A1', 'WA': '98003'}

# %%
zip_online.keys()
# Out:
# dict_keys(['ON', 'CO', 'TX', 'NY', 'NS', 'PQ', 'BC', 'WA'])

# %%
for i in not_found:
    for j in zip_online.keys():
        if df.loc[i]['Merch state'] == j:
            df.loc[df.index == i,'Merch zip'] = zip_online[j]

# %%
df[df.index.isin(not_found)]
# Out:
#        Recnum     Cardnum       Date       Merchnum  \
# 10486   10487  5142227402 2010-02-14            NaN
# 13934   13935  5142120389 2010-02-28            NaN
# 20802   20803  5142196337 2010-03-22            NaN
# 20866   20867  5142196337 2010-03-22            NaN
# 21063   21064  5142196337 2010-03-22            NaN
# 21102   21103  5142196337 2010-03-22            NaN
# 22444   22445  5142120389 2010-03-28            NaN
# 30626   30627  5142182005 2010-04-27  6497600064127
# 34906   34907  5142189108 2010-05-11            NaN
# 39956   39957  5142189135 2010-05-29  9006005990206
# 44858   44859  5142296516 2010-06-15            NaN
# 46519   46520  5142115062 2010-06-20            NaN
# 63494   63495  5142309462 2010-08-15   500020081506
# 65288   65289  5142119910 2010-08-21   500020081506
# 65526   65527  5142271289 2010-08-21   500020081506
# 65872   65873  5142276356 2010-08-22            NaN
# 66037   66038  5142188276 2010-08-23            NaN
# 72176   72177  5142250124 2010-09-11  6700017150060
# 72592   72593  5142176897 2010-09-12  9341690509209
# 72957   72958  5142176897 2010-09-13  9341690509209
# 74932   74933  5142250124 2010-09-19  6700017150060
# 75711   75712  5142147188 2010-09-20            NaN
# 80647   80648  5142120389 2010-10-08            NaN
# 88727   88728  5142233478 2010-11-22            NaN
# 95267   95268  5142174305 2010-12-22            NaN
#
#                Merch description Merch state Merch zip Transtype   Amount  \
# 10486     NORTHWEST ECONOMETRICS          BC   V5K 0A1         P   577.00
# 13934  LANGEVIN LEARN SERV(US)IN          ON   K0G 0A0         P   259.35
# 20802  LANGEVIN LEARNING SERVICE          ON   K0G 0A0         P   399.00
# 20866  LANGEVIN LEARNING SERVICE          ON   K0G 0A0         P   199.00
# 21063  LANGEVIN LEARNING SERVICE          ON   K0G 0A0         P   359.00
# 21102  LANGEVIN LEARNING SERVICE          ON   K0G 0A0         P   199.00
# 22444  LANGEVIN LEARN SERV(US)IN          ON   K0G 0A0         P   399.00
# 30626       JONES CHROMATOGRAPHY          CO     80218         P  1479.00
# 34906                  GOC-CCOHS          ON   K0G 0A0         P   365.00
# 39956             LYNNON BIOSOFT          PQ   G0A 0A0         P   468.00
# 44858     EXIT O DIGITAL SYSTEMS          NS   B0A 0A0         P   109.95
# 46519     EXIT O DIGITAL SYSTEMS          NS   B0A 0A0         P    69.95
# 63494           U S G S-RMMC-FIN          CO     80218         P   297.00
# 65288           U S G S-RMMC-FIN          CO     80218         P    65.00
# 65526           U S G S-RMMC-FIN          CO     80218         P    13.00
# 65872  LANGEVIN LEARN SERV(US)IN          ON   K0G 0A0         P   399.00
# 66037     ECOPOINT/DIESELNET INC          ON   K0G 0A0         P   125.00
# 72176     TEXSUN TROPHIE67650010          TX     75001         P   200.00
# 72592  ELEMENT K PRESS STORE.COM          NY     10081         P   163.85
# 72957  ELEMENT K PRESS STORE.COM          NY     10081         P    27.99
# 74932     TEXSUN TROPHIE67650010          TX     75001         P   345.58
# 75711                  GOC-CCOHS          ON   K0G 0A0         P   319.59
# 80647  LANGEVIN LEARNING SERVICE          ON   K0G 0A0         P   259.35
# 88727                  GOC-CCOHS          ON   K0G 0A0         P   360.00
# 95267                  GOC-CCOHS          ON   K0G 0A0         P   435.00
#
#        Fraud
# 10486      0
# 13934      0
# 20802      0
# 20866      0
# 21063      0
# 21102      0
# 22444      0
# 30626      0
# 34906      0
# 39956      0
# 44858      0
# 46519      0
# 63494      0
# 65288      0
# 65526      0
# 65872      0
# 66037      0
# 72176      0
# 72592      0
# 72957      0
# 74932      0
# 75711      0
# 80647      0
# 88727      0
# 95267      0

# %% [markdown]
# ### Fix Missing state and corresponding zip

# %%
df[df['Merch state'].isnull()]['Merch description'].value_counts()
# Out:
# RETAIL CREDIT ADJUSTMENT     357
# RETAIL DEBIT ADJUSTMENT      295
# ELSEVIER SCIENCE BV           58
# XFR F/VILLARREAL 12637808     19
# CREDIT PURCHASE BALANCE       19
#                             ...
# WWW.ALTA4.DE                   1
# IDEAL SOFTWARE                 1
# TOMORROW MAGAZINE              1
# VIEWEG FRIEDRICH & SOHN        1
# CAMPDEN PUBLISHING LTD         1
# Name: Merch description, Length: 151, dtype: int64

# %%
df[df['Merch state'].isnull()]['Fraud'].value_counts()
# Out:
# 0    1018
# 1       3
# Name: Fraud, dtype: int64

# %% [markdown]
# **Step 1: Fix missing state and zip for two adjustments with previous records if cardnum and description are same**

# %%
temp1 = df[df['Merch description'].isin(['RETAIL CREDIT ADJUSTMENT', 'RETAIL DEBIT ADJUSTMENT']) & 
          df['Merch state'].isnull()]

temp2 = df[df['Merch description'].isin(['RETAIL CREDIT ADJUSTMENT', 'RETAIL DEBIT ADJUSTMENT']) & 
          df['Merch state'].notnull()]


for i in temp1.index:
    for j in temp2.index:
        if (df.loc[i]['Cardnum'] == df.loc[j]['Cardnum']) & (
            df.loc[i]['Merch description'] == df.loc[j]['Merch description']):
            df.loc[df.index==i,'Merch state'] = df.loc[j]['Merch state']
            df.loc[df.index==i,'Merch zip'] = df.loc[j]['Merch zip']

# %% [markdown]
# **Step 2: Fix missing state and zip for two adjustments with most state and zip appeared for these two adjustments**

# %%
df[df['Merch description'].isin(['RETAIL CREDIT ADJUSTMENT', 'RETAIL DEBIT ADJUSTMENT']) & 
          df['Merch state'].notnull()][['Merch state','Merch zip']].value_counts()
# Out:
# Merch state  Merch zip
# VA           23229                   48
# GA           30326                    9
# DC           District of Columbia     9
# VA           23605                    8
# CA           03103                    6
# DC           20009                    5
# GA           43512                    4
# MD           21076                    3
# TX           76133                    1
# dtype: int64

# %%
temp = df[df['Merch description'].isin(['RETAIL CREDIT ADJUSTMENT', 'RETAIL DEBIT ADJUSTMENT']) & 
          df['Merch state'].isnull()]

for i in temp.index:
    df.loc[df.index == i, 'Merch state'] = 'VA'
    df.loc[df.index == i, 'Merch zip'] = '23229'

# %% [markdown]
# **Step 3: other missing, fix with mode**

# %%
df[df['Merch state'].isnull()]
# Out:
#        Recnum     Cardnum       Date       Merchnum        Merch description  \
# 931       932  5142214551 2010-01-06        6176269       MUNKSGAARDS FORLAG
# 1275     1276  5142158180 2010-01-07            NaN        BLACKWELL SCIENCE
# 1402     1403  5142159706 2010-01-07              0   INTERACTIVE SOFTWARE S
# 1561     1562  5142214551 2010-01-10            NaN      ELSEVIER SCIENCE BV
# 2042     2043  5142214551 2010-01-11        6176269       MUNKSGAARDS FORLAG
# ...       ...         ...        ...            ...                      ...
# 91980   91981  5142111372 2010-12-08              0            CATCHWORD LTD
# 92921   92922  5142197979 2010-12-13            NaN  IARC PRESS VAD  2184997
# 93146   93147  5142224426 2010-12-14  8457033078615    GREEN LEAF PUBLISHING
# 93760   93761  5142195916 2010-12-15              0   REED BUSINESS PUBLISHI
# 94752   94753  5142283373 2010-12-20            NaN        TOMORROW MAGAZINE
#
#       Merch state Merch zip Transtype   Amount  Fraud
# 931           NaN       0.0         P  1790.00      0
# 1275          NaN       0.0         P   584.90      0
# 1402          NaN       0.0         P   460.00      0
# 1561          NaN       0.0         P  1053.00      0
# 2042          NaN       0.0         P  3100.00      0
# ...           ...       ...       ...      ...    ...
# 91980         NaN       0.0         P    19.39      0
# 92921         NaN       0.0         P   260.00      0
# 93146         NaN       0.0         P    24.95      0
# 93760         NaN       0.0         P   140.00      0
# 94752         NaN       0.0         P   850.00      0
#
# [369 rows x 10 columns]

# %%
df[df['Merch state'].isnull()]['Fraud'].value_counts()
# Out:
# 0    367
# 1      2
# Name: Fraud, dtype: int64

# %%
df.loc[df['Fraud'] == 0][['Merch state','Merch zip']].mode()
# Out:
#   Merch state Merch zip
# 0          TN   38118.0

# %%
df.loc[df['Fraud'] == 1][['Merch state','Merch zip']].mode()
# Out:
#   Merch state Merch zip
# 0          WA   98101.0

# %%
# fix other missing state and missing zip by mode in each class
temp = df[df['Merch state'].isnull()]

for i in temp.index:
    if df.loc[i]['Fraud'] == 0:
        df.loc[df.index == i, 'Merch state'] = 'TN'
        df.loc[df.index == i, 'Merch zip'] = '38118'
    else:
        df.loc[df.index == i, 'Merch state'] = 'WA'
        df.loc[df.index == i, 'Merch zip'] = '98101'

# %%
df[df['Merch state'].isnull()].sum()
# Out:
# Recnum               0.0
# Cardnum              0.0
# Date                 0.0
# Merchnum             0.0
# Merch description    0.0
# Merch state          0.0
# Merch zip            0.0
# Transtype            0.0
# Amount               0.0
# Fraud                0.0
# dtype: float64

# %%
df[df['Merch zip'].isnull()].sum()
# Out:
# Recnum               0.0
# Cardnum              0.0
# Date                 0.0
# Merchnum             0.0
# Merch description    0.0
# Merch state          0.0
# Merch zip            0.0
# Transtype            0.0
# Amount               0.0
# Fraud                0.0
# dtype: float64

# %%
len(df[df['Merch zip'] == 0])
# Out:
# 0

# %% [markdown]
# ### Fix missing Merchnum

# %%
df.isnull().sum()
# Out:
# Recnum                  0
# Cardnum                 0
# Date                    0
# Merchnum             3199
# Merch description       0
# Merch state             0
# Merch zip               0
# Transtype               0
# Amount                  0
# Fraud                   0
# dtype: int64

# %%
# make the missing to '0' and then fix together
df['Merchnum'] = df['Merchnum'].fillna('0')

# %%
# fill missing and bad Merchnum with values from other records that 
# share the same Merch description, Merch state and Merch zip
temp1 = df[df['Merchnum'].isin(['0'])] 
temp2 = df[~df['Merchnum'].isin(['0'])] 
temp3 = df.groupby(['Merch description', 'Merch state', 'Merch zip'])

for i in temp1.index: 
    for j in temp3.groups[df.loc[i]['Merch description'], df.loc[i]['Merch state'], df.loc[i]['Merch zip']]:
        if j in temp2.index:
            df.loc[df.index == i, 'Merchnum'] = df.loc[j]['Merchnum']

# %%
df[df['Merchnum'].isin(['0'])]
# Out:
#        Recnum     Cardnum       Date Merchnum          Merch description  \
# 201       202  5142140436 2010-01-03        0   MONTGOMERY COLLEGE-PHONE
# 262       263  5142257575 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 272       273  5142124791 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 400       401  5142276099 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 476       477  5142267793 2010-01-05        0    RETAIL DEBIT ADJUSTMENT
# ...       ...         ...        ...      ...                        ...
# 96621   96622  5142253938 2010-12-30        0  OREGON ENVIRONMENTAL COUN
# 96651   96652  5142151962 2010-12-30        0    RETAIL DEBIT ADJUSTMENT
# 96689   96690  5142166019 2010-12-30        0     ADVANCED SEC & CONTROL
# 96720   96721  5142178272 2010-12-31        0           TRULOGIC SYSTEMS
# 96730   96731  5142122644 2010-12-31        0    RETAIL DEBIT ADJUSTMENT
#
#       Merch state Merch zip Transtype  Amount  Fraud
# 201            MD   20850.0         P  266.00      0
# 262            VA     23229         P  320.00      0
# 272            VA     23229         P  970.00      0
# 400            VA     23229         P   82.59      0
# 476            VA     23229         P   17.59      0
# ...           ...       ...       ...     ...    ...
# 96621          OR   97204.0         P   40.00      0
# 96651          VA     23229         P  125.00      0
# 96689          GA   30340.0         P   70.50      0
# 96720          ON     01930         P  343.42      0
# 96730          VA     23229         P  340.79      0
#
# [2188 rows x 10 columns]

# %%
# fill missing and bad Merchnum with values from other records that share the same Merch description, Merch state
temp1 = df[df['Merchnum'].isin(['0'])] 
temp2 = df[~df['Merchnum'].isin(['0'])] 
temp3 = df.groupby(['Merch description', 'Merch state'])

for i in temp1.index: 
    for j in temp3.groups[df.loc[i]['Merch description'], df.loc[i]['Merch state']]:
        if j in temp2.index:
            df.loc[df.index == i, 'Merchnum'] = df.loc[j]['Merchnum']

# %%
df[df['Merchnum'].isin(['0'])]
# Out:
#        Recnum     Cardnum       Date Merchnum          Merch description  \
# 201       202  5142140436 2010-01-03        0   MONTGOMERY COLLEGE-PHONE
# 262       263  5142257575 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 272       273  5142124791 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 400       401  5142276099 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 476       477  5142267793 2010-01-05        0    RETAIL DEBIT ADJUSTMENT
# ...       ...         ...        ...      ...                        ...
# 96621   96622  5142253938 2010-12-30        0  OREGON ENVIRONMENTAL COUN
# 96651   96652  5142151962 2010-12-30        0    RETAIL DEBIT ADJUSTMENT
# 96689   96690  5142166019 2010-12-30        0     ADVANCED SEC & CONTROL
# 96720   96721  5142178272 2010-12-31        0           TRULOGIC SYSTEMS
# 96730   96731  5142122644 2010-12-31        0    RETAIL DEBIT ADJUSTMENT
#
#       Merch state Merch zip Transtype  Amount  Fraud
# 201            MD     20850         P  266.00      0
# 262            VA     23229         P  320.00      0
# 272            VA     23229         P  970.00      0
# 400            VA     23229         P   82.59      0
# 476            VA     23229         P   17.59      0
# ...           ...       ...       ...     ...    ...
# 96621          OR     97204         P   40.00      0
# 96651          VA     23229         P  125.00      0
# 96689          GA     30340         P   70.50      0
# 96720          ON     01930         P  343.42      0
# 96730          VA     23229         P  340.79      0
#
# [2111 rows x 10 columns]

# %%
# fill missing and bad Merchnum with values from other records that share the same Merch description
temp1 = df[df['Merchnum'].isin(['0'])] 
temp2 = df[~df['Merchnum'].isin(['0'])] 
temp3 = df.groupby(['Merch description'])

for i in temp1.index: 
    for j in temp3.groups[df.loc[i]['Merch description']]:
        if j in temp2.index:
            df.loc[df.index == i, 'Merchnum'] = df.loc[j]['Merchnum']

# %%
df[df['Merchnum'].isin(['0'])]
# Out:
#        Recnum     Cardnum       Date Merchnum          Merch description  \
# 201       202  5142140436 2010-01-03        0   MONTGOMERY COLLEGE-PHONE
# 262       263  5142257575 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 272       273  5142124791 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 400       401  5142276099 2010-01-04        0    RETAIL DEBIT ADJUSTMENT
# 476       477  5142267793 2010-01-05        0    RETAIL DEBIT ADJUSTMENT
# ...       ...         ...        ...      ...                        ...
# 96621   96622  5142253938 2010-12-30        0  OREGON ENVIRONMENTAL COUN
# 96651   96652  5142151962 2010-12-30        0    RETAIL DEBIT ADJUSTMENT
# 96689   96690  5142166019 2010-12-30        0     ADVANCED SEC & CONTROL
# 96720   96721  5142178272 2010-12-31        0           TRULOGIC SYSTEMS
# 96730   96731  5142122644 2010-12-31        0    RETAIL DEBIT ADJUSTMENT
#
#       Merch state Merch zip Transtype  Amount  Fraud
# 201            MD     20850         P  266.00      0
# 262            VA     23229         P  320.00      0
# 272            VA     23229         P  970.00      0
# 400            VA     23229         P   82.59      0
# 476            VA     23229         P   17.59      0
# ...           ...       ...       ...     ...    ...
# 96621          OR     97204         P   40.00      0
# 96651          VA     23229         P  125.00      0
# 96689          GA     30340         P   70.50      0
# 96720          ON     01930         P  343.42      0
# 96730          VA     23229         P  340.79      0
#
# [2094 rows x 10 columns]

# %%
# fill others with "Unknown"
df['Merchnum'] = df['Merchnum'].replace('0','unknown')

# %% [markdown]
# ### Final Dataset

# %%
# remove the single large amount transaction
df = df.drop(index = [52714])

# %%
# change zipcode to 5 digits if it is U.S. code
for i in df.index:
    if df.loc[i]['Merch zip'][:5].isdecimal():
        df.loc[df.index == i, 'Merch zip'] = df.loc[i]['Merch zip'][:5]

# %%
df.isnull().sum()
# Out:
# Recnum               0
# Cardnum              0
# Date                 0
# Merchnum             0
# Merch description    0
# Merch state          0
# Merch zip            0
# Transtype            0
# Amount               0
# Fraud                0
# dtype: int64

# %%
#df.to_csv('clean card transaction.csv')
